# %% [markdown]
# Introduction to sql
#
# what is data base
#
# types of database
#
# database structure
#
# what is table
#
#  creationg our first database
#
#  creating our first table
#
#  sql datatypes
#
#  types of sql commands
#
#  database related queries
#
#  table related queries
#
#  select command
#
#  insert command
#
#  insert command
#
#  keys
#
#  constraints
#  .
#  select command in detail
#
#  where clause
#
#  operators
#
#  limit clause
#
#  order bye clause
#
#  aggregate function
#
#  group by clause
#
#  having clause
#
#  general order of commands
#
#  update command
#
#  delete command
#
#  revisitiong foreign keys
#
#  cascading foreign keys
#
#  alter command
#
#  change and modify commands
#
#  truncate command
#
#  joins in sql
#
#  union in sql
#
#  mysql queries
#
#  mysql views
